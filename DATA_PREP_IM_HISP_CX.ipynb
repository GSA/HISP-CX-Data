# %%
## written by I/Users/isabelmetzger/Downloads/tzger
# last updated May 21, 2023

# this jupyter notebook calls data from performance.gov and merges them into a table for further downstream analysis + data products (e.g., Tableau Dashboard)

import pandas as pd
import requests
import datetime
import warnings
from IPython.display import display, HTML
import time
# adding simple warning filter
warnings.simplefilter('ignore')



# adding date
today = datetime.datetime.today().strftime('%Y-%m-%d')
print(f"{today}")
# Out:
# 2023-05-21

# %%
# creating function for flattening json/dictionary

def flatten_json(y):
    """
    this flattens_json obj
    adds begining key to beginning
    """
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
base_url = "https://www.performance.gov/cx/data/"

data2definition = {
"service_providers" : "A list of High Impact Service Providers (HISPs).",
"services" : "A list of Services. Each HISP has one or more Services.",
"collections" : "HISPs are required to report their customer feedback for each service quarterly; this file includes one record for each quarterly report",
"omb_cx_reporting_collections" : "This file includes one or more Report Detail records per Data Collection",
}

# %%
data_dict = {}

for k in data2definition.keys():
    data_url = f"{base_url}{k}.json"
    print("calling", data_url)
    print()
    data_ = requests.get(data_url).json()
    time.sleep(5)
    data_dict[k] = data_
# Out:
# calling https://www.performance.gov/cx/data/service_providers.json
#
# calling https://www.performance.gov/cx/data/services.json
#
# calling https://www.performance.gov/cx/data/collections.json
#
# calling https://www.performance.gov/cx/data/omb_cx_reporting_collections.json

# %%
omb_df = pd.DataFrame(flatten_json(a) for a in data_dict['omb_cx_reporting_collections']['data'])
omb_df.head()
# Out:
#   id                          type  attributes_organization_id  \
# 0  1  omb_cx_reporting_collections                        2129
# 1  2  omb_cx_reporting_collections                        2111
# 2  3  omb_cx_reporting_collections                        2111
# 3  4  omb_cx_reporting_collections                        2106
# 4  5  omb_cx_reporting_collections                        2106
#
#       attributes_organization_name attributes_organization_abbreviation  \
# 0   Department of Veterans Affairs                                   VA
# 1          Department of Education                                   ED
# 2          Department of Education                                   ED
# 3  Office of Personnel Management                                   OPM
# 4  Office of Personnel Management                                   OPM
#
#    attributes_service_provider_id attributes_service_provider_name  \
# 0                              21   Veterans Health Administration
# 1                              15              Federal Student Aid
# 2                              15              Federal Student Aid
# 3                              13              Retirement Services
# 4                              13              Retirement Services
#
#    attributes_collection_id attributes_collection_name  \
# 0                         1     CX Quarterly Reporting
# 1                         2     CX Quarterly Reporting
# 2                         2     CX Quarterly Reporting
# 3                         3     CX Quarterly Reporting
# 4                         3     CX Quarterly Reporting
#
#   attributes_collection_year  ... attributes_q11_3 attributes_q11_4  \
# 0                       2021  ...                0                0
# 1                       2021  ...                0                0
# 2                       2021  ...                0                0
# 3                       2021  ...                0                0
# 4                       2021  ...                0                0
#
#   attributes_q11_5 attributes_q11_point_scale     attributes_created_at  \
# 0                0                        NaN  2021-05-13T23:05:19.090Z
# 1                0                        NaN  2021-05-14T05:25:07.624Z
# 2                0                        NaN  2021-05-14T05:33:29.668Z
# 3                0                        NaN  2021-05-14T06:09:22.216Z
# 4                0                        NaN  2021-05-14T06:17:22.773Z
#
#       attributes_updated_at  attributes_operational_metrics  \
# 0  2021-08-04T19:44:05.084Z
# 1  2021-08-04T19:21:24.493Z
# 2  2021-08-04T19:21:18.048Z
# 3  2021-08-09T05:16:06.129Z
# 4  2021-08-04T19:47:06.723Z
#
#   attributes_service_id           attributes_service_name  \
# 0                     2     Receiving outpatient services
# 1                    22        Applying for Financial Aid
# 2                    22        Applying for Financial Aid
# 3                    18  Applying for retirement benefits
# 4                    18  Applying for retirement benefits
#
#   attributes_service_slug
# 0                  va-vha
# 1                  ed-fsa
# 2                  ed-fsa
# 3                  opm-rs
# 4                  opm-rs
#
# [5 rows x 102 columns]

# %%
collection_cols = [
     'collection_id',
     'start_date',
     'end_date',
     'year',
     'quarter',
     'integrity_hash',
     'aasm_state',
     'reflection',
     'rating',
     'user_id',
     'updated_at_collection',
    'number_relationship_links'
                  ]

collection_df = pd.DataFrame( data_dict['collections']['data'])
collection_df = collection_df.drop(columns=['attributes']).merge(collection_df['attributes'].apply(pd.Series), right_index=True, left_index=True)

collection_df['collection_id'] = collection_df['id'].map(str)

collection_df['number_relationship_links'] = collection_df['relationships'].map(lambda x: x.get('omb_cx_reporting_collections', {}).get('data', [])).map(len)
display(collection_df.head())
# Out:
#   id         type                                      relationships  \
# 0  1  collections  {'omb_cx_reporting_collections': {'data': [{'i...
# 1  2  collections  {'omb_cx_reporting_collections': {'data': [{'i...
# 2  3  collections  {'omb_cx_reporting_collections': {'data': [{'i...
# 3  4  collections  {'omb_cx_reporting_collections': {'data': [{'i...
# 4  6  collections  {'omb_cx_reporting_collections': {'data': [{'i...
#
#                      name  start_date    end_date  organization_id  \
# 0  CX Quarterly Reporting  2021-01-01  2021-03-31             2129
# 1  CX Quarterly Reporting  2021-01-01  2021-03-31             2111
# 2  CX Quarterly Reporting  2021-01-01  2021-03-31             2106
# 3  CX Quarterly Reporting  2021-01-01  2021-03-31             2106
# 4  CX Quarterly Reporting  2021-01-01  2021-03-31             2098
#
#                  organization_name organization_abbreviation  year  ...  \
# 0   Department of Veterans Affairs                        VA  2021  ...
# 1          Department of Education                        ED  2021  ...
# 2  Office of Personnel Management                        OPM  2021  ...
# 3  Office of Personnel Management                        OPM  2021  ...
# 4        Department of Agriculture                      USDA  2021  ...
#
#   service_provider_id           service_provider_name integrity_hash  \
# 0                  21  Veterans Health Administration           None
# 1                  15             Federal Student Aid           None
# 2                  13             Retirement Services           None
# 3                  12     Federal Employment Services           None
# 4                   5                  Recreation.gov           None
#
#   aasm_state                                         reflection rating  \
# 0  published  The insights collected digitally enabled veter...   TRUE
# 1  published  For the FAFSA.gov customer satisfaction survey...   TRUE
# 2  published  For Retirement Services:\r\nOverall, Q2 percen...   TRUE
# 3  published  USAJOBS Desktop (Summary FY 2021 Q2)\r\n\r\nWh...   TRUE
# 4  published  In the second quarter of FY2021 (January - Mar...   TRUE
#
#   user_id                updated_at collection_id number_relationship_links
# 0       1  2021-08-04T16:46:59.914Z             1                         1
# 1      87  2021-08-04T16:41:37.845Z             2                         2
# 2       1  2021-08-04T16:59:16.957Z             3                         2
# 3       1  2021-08-04T16:59:39.986Z             4                         2
# 4       1  2021-08-04T16:40:22.666Z             6                         1
#
# [5 rows x 21 columns]

# %%
services = pd.DataFrame(d for d in data_dict['services']['data'])
services_df = pd.concat([services[['id', 'type']], services['attributes'].apply(pd.Series)], axis=1)
display(services_df.head(2))

service_providers_df = pd.DataFrame(flatten_json(a) for a in data_dict['service_providers']['data'])
serviceproviderid2desc = service_providers_df.set_index('id')['attributes_description'].to_dict()
display(service_providers_df.head(2))

serviceid2desc = services_df.set_index('id')['description'].to_dict()
# Out:
#   id      type                           name  \
# 0  1  services                    Touchpoints
# 1  2  services  Receiving outpatient services
#
#                                          description  organization_id  \
# 0  Making customer feedback easier for federal ag...                1
# 1  VHA sends email surveys to everyone who receiv...             2129
#
#   organization_abbreviation                organization_name  \
# 0                       GSA  General Services Administration
# 1                        VA   Department of Veterans Affairs
#
#    service_provider_id           service_provider_name justification_text  \
# 0                 44.0       Non-HISP Service Provider
# 1                 21.0  Veterans Health Administration
#
#    ... service_slug            service_owner_email  \
# 0  ...                           ryan.wold@gsa.gov
# 1  ...       va-vha  aaron.m.stienstra@omb.eop.gov
#
#                                     service_managers  \
# 0  [{'email': 'philip.ashlock@gsa.gov', 'first_na...
# 1                                                 []
#
#                                 url                      homepage_url  \
# 0  https://touchpoints.digital.gov/  https://touchpoints.digital.gov/
# 1                                                                None
#
#                                             channels  \
# 0  [{'id': 315, 'name': 'email', 'created_at': '2...
# 1                                                 []
#
#                                                 tags available_in_person  \
# 0  [{'id': 218, 'name': 'surveys', 'created_at': ...               False
# 1                                                 []               False
#
#   available_digitally available_via_phone
# 0                True                True
# 1               False               False
#
# [2 rows x 27 columns]
#    id               type  attributes_organization_id  \
# 0  36  service_providers                        2098
# 1  28  service_providers                        2098
#
#   attributes_organization_abbreviation attributes_organization_name  \
# 0                                 USDA    Department of Agriculture
# 1                                 USDA    Department of Agriculture
#
#                attributes_name attributes_slug  \
# 0          Farm Service Agency        usda-fsa
# 1  Food and Nutrition Service         usda-fns
#
#                               attributes_description attributes_notes  \
# 0  The Farm Service Agency (FSA) serves all farme...
# 1  Food and Nutrition Service (FNS) works to end ...
#
#             attributes_department  ... attributes_url attributes_new  \
# 0                            usda  ...           None          False
# 1  Recertifying WIC participation  ...           None           True
#
#    attributes_services_count attributes_cx_maturity_mapping_value  \
# 0                          2                                    4
# 1                          2                                    7
#
#    attributes_impact_mapping_value  \
# 0                               30
# 1                               25
#
#    attributes_service_provider_managers_0_email  \
# 0                                          None
# 1                                          None
#
#    attributes_service_provider_managers_0_first_name  \
# 0                                                NaN
# 1                                                NaN
#
#    attributes_service_provider_managers_0_last_name  \
# 0                                               NaN
# 1                                               NaN
#
#   attributes_service_provider_managers_0_position_title  \
# 0                                                NaN
# 1                                                NaN
#
#    attributes_service_provider_managers_0_profile_photo
# 0                                                NaN
# 1                                                NaN
#
# [2 rows x 23 columns]

# %%
# mapping service desc
omb_df['service_desc'] = omb_df['attributes_service_id'].map(str).map(lambda x: serviceid2desc.get(x ))

# mapping service provider desc
omb_df['service_provider_desc'] = omb_df['attributes_service_provider_id'].map(lambda x: serviceproviderid2desc.get(str(x))
                                                                              )
display(omb_df.sample(2))
# Out:
#       id                          type  attributes_organization_id  \
# 352  532  omb_cx_reporting_collections                        2135
# 106  194  omb_cx_reporting_collections                        2096
#
#                     attributes_organization_name  \
# 352                   Department of the Interior
# 106  Department of Housing and Urban Development
#
#     attributes_organization_abbreviation  attributes_service_provider_id  \
# 352                                  DOI                              37
# 106                                  HUD                              11
#
#     attributes_service_provider_name  attributes_collection_id  \
# 352        Fish and Wildlife Service                       201
# 106    Housing and Urban Development                        59
#
#     attributes_collection_name attributes_collection_year  ...  \
# 352     CX Quarterly Reporting                       2022  ...
# 106     CX Quarterly Reporting                       2021  ...
#
#     attributes_q11_5 attributes_q11_point_scale     attributes_created_at  \
# 352                0                        NaN  2022-10-03T13:03:31.988Z
# 106                0                        NaN  2021-07-02T21:52:01.975Z
#
#         attributes_updated_at  attributes_operational_metrics  \
# 352  2022-10-03T13:03:31.988Z
# 106  2021-08-04T19:31:29.692Z
#
#      attributes_service_id                            attributes_service_name  \
# 352                     99  Planning a trip to a national wildlife refuge ...
# 106                     15  Seeking information about FHA loan programs an...
#
#     attributes_service_slug  \
# 352
# 106                 hud-fha
#
#                                           service_desc  \
# 352  Customers of the U.S. Fish and Wildlife websit...
# 106  Trying to buy, maintain, keep and/or sell a ho...
#
#                                  service_provider_desc
# 352  The U.S. Fish and Wildlife Service is the prem...
# 106  In 2020, the Department of Housing and Urban D...
#
# [2 rows x 104 columns]

# %%
omb_df.to_csv(f"./mergedcxdata-{today}.csv", index=False)
